# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns=30
pd.options.display.float_format='{:.2f}'.format

# %% [markdown]
# # Parte 1

# %%
#parse_dates converte em data
data=pd.read_csv("movies_complete.csv",parse_dates=["release_date"])
#Verificando o tipo das colunas
print(data.dtypes)
# Out:
# id                                int64
# title                            object
# tagline                          object
# release_date             datetime64[ns]
# genres                           object
# belongs_to_collection            object
# original_language                object
# budget_musd                     float64
# revenue_musd                    float64
# production_companies             object
# production_countries             object
# vote_count                      float64
# vote_average                    float64
# popularity                      float64
# runtime                         float64
# overview                         object
# spoken_languages                 object
# poster_path                      object
# cast                             object
# cast_size                         int64
# crew_size                         int64
# director                         object
# dtype: object

# %%
data.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
#Vendo os dados do dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
# id                       44691 non-null int64
# title                    44691 non-null object
# tagline                  20284 non-null object
# release_date             44657 non-null datetime64[ns]
# genres                   42586 non-null object
# belongs_to_collection    4463 non-null object
# original_language        44681 non-null object
# budget_musd              8854 non-null float64
# revenue_musd             7385 non-null float64
# production_companies     33356 non-null object
# production_countries     38835 non-null object
# vote_count               44691 non-null float64
# vote_average             42077 non-null float64
# popularity               44691 non-null float64
# runtime                  43179 non-null float64
# overview                 43740 non-null object
# spoken_languages         41094 non-null object
# ...

# %%
data.title[1]
# Out:
# 'Jumanji'

# %%
#Deescreve as colunas numéricas.
data.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
data.hist(figsize=(20,12), bins=100)
plt.show()

# %%
print(data.budget_musd.value_counts(dropna=False).head(20))
print(data.revenue_musd.value_counts(dropna=False).head(20)) 
print(data.vote_average.value_counts(dropna=False).head(20))
print(data.vote_count.value_counts(dropna=False).head(20))
# Out:
# nan      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 0.50       141
# 35.00      141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64
# nan      37306
# 12.00       20
# 11.00       19
# 10.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 20.00       10
# 1.00        10
# 4.00         9
# 0.00         9
# 1.50         9
# 25.00        8
# 16.00        8
# Name: revenue_musd, dtype: int64
# nan     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
# 6.30    1583
# 5.50    1369
# 5.80    1358
# 6.40    1343
# 6.70    1328
# 6.80    1316
# 6.10    1274
# 6.60    1250
# 6.20    1240
# 5.90    1189
# 5.30    1068
# ...

# %%
#Descreve as colunas não numéricas
data.describe(include="object")
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
#Como temos um titulo com váris ocorrências vamos checar se elas realmente são valores duplicados.
data[data.title=="Cinderella"]
#Podemos verificar sque não são.
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# # Parte 2: Melhores e piores filmes.

# %%
from IPython.display import HTML

# %%
data_best=data[["poster_path","title","budget_musd","revenue_musd","vote_count","vote_average","popularity"]].copy()
data_best.head(5)
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity
# 0          7.70       21.95
# 1          6.90       17.02
# 2          6.50       11.71
# 3          6.10        3.86
# 4          5.70        8.39

# %%
data_best["profit_musd"]=data.revenue_musd.sub(data.budget_musd)
#data_best["profit_musd"]=data.revenue_musd - data.budget_musd
data_best["return"]=data.revenue_musd.div(data.budget_musd)
data_best.head(5)
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return
# 0          7.70       21.95       343.55   12.45
# 1          6.90       17.02       197.80    4.04
# 2          6.50       11.71          nan     nan
# ...

# %%
print(list(data_best.columns))
# Out:
# ['poster_path', 'title', 'budget_musd', 'revenue_musd', 'vote_count', 'vote_average', 'popularity', 'profit_musd', 'return']

# %%
data_best.columns=["","Title","Budget","Revenue","Votes","Average Rating","Popularity","Profit","ROI"]

# %%
data_best.set_index("Title", inplace=True)

# %%
data_best.head()
data_best[data_best.index=="Cinderella"]
# Out:
#                                                                Budget  \
# Title
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//avz6...    2.90
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//54aw...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//bL1K...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//rbzG...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//wjZK...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//iH4C...   95.00
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//p41r...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//cB6I...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//gMYk...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//cf0g...     nan
# Cinderella  <img src='http://image.tmdb.org/t/p/w185//nvGe...     nan
#
#             Revenue   Votes  Average Rating  Popularity  Profit   ROI
# Title
# ...

# %%
subset=data_best.iloc[:5,:2]
subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                nan
# Waiting to Exhale             16.00
# Father of the Bride Part II     nan

# %%
data_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
pd.options.display.max_colwidth = 200
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
data_best.sort_values(by = 'Average Rating', ascending=False)
# Out:
#                                                                                                                                                        \
# Title
# Portrait of a Young Man in Three Movements                                                                                                        NaN
# Brave Revolutionary                                 <img src='http://image.tmdb.org/t/p/w185//zAb2YxgYSJTcloGTHAA9ogOVq7M.jpg' style='height:100px;'>
# Other Voices Other Rooms                            <img src='http://image.tmdb.org/t/p/w185//4ifPBA4AjRQWxgVJAwSwWp6nFCa.jpg' style='height:100px;'>
# The Lion of Thebes                                  <img src='http://image.tmdb.org/t/p/w185//tdOcmIjI8sx9RZIsVgOlq4kQgJ4.jpg' style='height:100px;'>
# Katt Williams: Priceless: Afterlife                 <img src='http://image.tmdb.org/t/p/w185//wKrH5tKdJa3y5jqAQM1eYmkXbHX.jpg' style='height:100px;'>
# ...

# %%
data_best.sort_values(by = 'ROI', ascending=False)
# Out:
#                                                                                                                                      \
# Title
# Less Than Zero                    <img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'>
# Modern Times                      <img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'>
# Welcome to Dongmakgol              <img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'>
# Aquí Entre Nos                    <img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'>
# The Karate Kid, Part II           <img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'>
# Nurse 3-D                         <img src='http://image.tmdb.org/t/p/w185//ny0NZWQVlg6WNB8VYFDuzVQQW8v.jpg' style='height:100px;'>
# ...

# %%
data_best[data_best.Budget>=5].sort_values(by = 'ROI', ascending=False)
# Out:
#                                                                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
# ...

# %%
data_best.Budget.fillna(0,inplace=True)
data_best.Votes.fillna(0,inplace=True)

# %%
data_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#                   44467 non-null object
# Budget            44691 non-null float64
# Revenue           7385 non-null float64
# Votes             44691 non-null float64
# Average Rating    42077 non-null float64
# Popularity        44691 non-null float64
# Profit            5371 non-null float64
# ROI               5371 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 4.3+ MB

# %%
data_best.loc[(data_best.Votes>=5)].head(5)
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                              Budget  Revenue   Votes  Average Rating  \
# Title
# Toy Story                     30.00   373.55 5415.00            7.70
# ...

# %%
def best_worst(n,by,ascending=False,min_bud=0,min_votes=0):
    df2=data_best.loc[(data_best.Budget>=min_bud)&(data_best.Votes>=min_votes),["",by]].sort_values(by=by, ascending=ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %%
best_worst(n=5,by="Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %%
best_worst(5,"Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %%
best_worst(5,"Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %%
best_worst(5,"Profit", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %%
best_worst(5,"ROI",ascending=True, min_bud=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Lolita</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//unGWuk8kax8r4PlbGJL9y6WnfFx.jpg' style='height:100px;'></td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Child 44</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qqGhMt31HVUN3WnH0L2r0OWq38E.jpg' style='height:100px;'></td>
#       <td>0.07</td>
# ...

# %% [markdown]
# # Parte 3: Qual filme ver em seguida?

# %%
type(data.genres)
# Out:
# pandas.core.series.Series

# %%
type(data.genres.str.contains("Action"))
# Out:
# pandas.core.series.Series

# %%
search= data.genres.str.contains("Action") & data.genres.str.contains("Science Fiction") & data.cast.str.contains("Bruce Willis")
search
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 44661    False
# 44662    False
# 44663    False
# 44664    False
# 44665    False
# 44666    False
# 44667    False
# 44668    False
# 44669    False
# 44670    False
# 44671    False
# 44672    False
# 44673    False
# 44674    False
# 44675    False
# 44676    False
# 44677    False
# 44678    False
# 44679    False
# 44680    False
# 44681    False
# 44682    False
# 44683    False
# 44684    False
# 44685    False
# 44686    False
# 44687    False
# ...

# %%
filter_data=data.loc[search,["title","poster_path","vote_average"]].sort_values(by="vote_average", ascending=False)
filter_data
# Out:
#                        title  \
# 1448       The Fifth Element
# 19218                 Looper
# 1786              Armageddon
# 14135             Surrogates
# 20333  G.I. Joe: Retaliation
# 27619                   Vice
#
#                                                                                              poster_path  \
# 1448   <img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'>
# 19218  <img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'>
# 1786   <img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'>
# 14135   <img src='http://image.tmdb.org/t/p/w185//v3Z0Hbl0oe57njrrIPh0fJPFoo.jpg' style='height:100px;'>
# 20333  <img src='http://image.tmdb.org/t/p/w185//3rWIZMzTKcCtV0eHJ70Z4Ru659f.jpg' style='height:100px;'>
# 27619  <img src='http://image.tmdb.org/t/p/w185//nPqNoQ55RIrmmo9mpqg1jE3ENza.jpg' style='height:100px;'>
#
#        vote_average
# ...

# %%
HTML(filter_data.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
# ...

# %%
data.director
# Out:
# 0              John Lasseter
# 1               Joe Johnston
# 2              Howard Deutch
# 3            Forest Whitaker
# 4              Charles Shyer
# 5               Michael Mann
# 6             Sydney Pollack
# 7               Peter Hewitt
# 8                Peter Hyams
# 9            Martin Campbell
# 10                Rob Reiner
# 11                Mel Brooks
# 12               Simon Wells
# 13              Oliver Stone
# 14              Renny Harlin
# 15           Martin Scorsese
# 16                   Ang Lee
# 17            Allison Anders
# 18            Steve Oedekerk
# 19              Joseph Ruben
# 20          Barry Sonnenfeld
# 21                 Jon Amiel
# 22            Richard Donner
# 23              Victor Salva
# 24               Mike Figgis
# 25             Oliver Parker
# 26       Lesli Linka Glatter
# 27             Roger Michell
# 28        Jean-Pierre Jeunet
# 29               Zhang Yimou
#                 ...
# 44661         Oleg Assadulin
# ...

# %%
filter=(data.director=='Quentin Tarantino') & (data.cast.str.contains("Uma Thurman"))

# %%
type(filter)
filter.describe()
# Out:
# count     44691
# unique        2
# top       False
# freq      44688
# dtype: object

# %%
result =data.loc[filter,["title","poster_path","runtime"]].sort_values(by="runtime").set_index("title")
result
# Out:
#                                                                                                          poster_path  \
# title
# Kill Bill: Vol. 1  <img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'>
# Kill Bill: Vol. 2  <img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'>
# Pulp Fiction       <img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'>
#
#                    runtime
# title
# Kill Bill: Vol. 1   111.00
# Kill Bill: Vol. 2   136.00
# Pulp Fiction        154.00

# %%
HTML(result.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(data.production_companies.describe())
print(data.production_companies.isna().sum())
# Out:
# count                         33356
# unique                        22537
# top       Metro-Goldwyn-Mayer (MGM)
# freq                            741
# Name: production_companies, dtype: object
# 11335

# %%
filter= (data.production_companies.str.contains("Pixar").fillna(False)) & (data.release_date.between("2010-01-01","2015-12-31"))
print(filter.describe())
result =data.loc[filter,["title","poster_path","revenue_musd","release_date"]].sort_values(by="revenue_musd", ascending =False).set_index("title")
HTML(result.to_html(escape=False))
# Out:
# count     44691
# unique        2
# top       False
# freq      44672
# dtype: object
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
# ...

# %%
filter = (data.genres.str.contains("Action") | data.genres.str.contains("Thriller")) & (data.original_language=="en")
print(filter.describe())
result =data.loc[filter,["title","poster_path","genres","vote_average","vote_count","release_date"]].sort_values(by="release_date", ascending =False).set_index("title").head(20)
HTML(result.to_html(escape=False))
# Out:
# count     44691
# unique        2
# top       False
# freq      35921
# dtype: object
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>What Happened to Monday</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//o6EsOqITcSzcdwD1zxBM9imdxjr.jpg' style='height:100px;'></td>
#       <td>Science Fiction|Thriller</td>
#       <td>7.30</td>
#       <td>598.00</td>
#       <td>2017-08-18</td>
#     </tr>
#     <tr>
#       <th>Kidnap</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aDv28U8Ug0uKniURZQ6gpevRMVU.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller</td>
# ...

# %% [markdown]
# # Parte 4

# %%
from wordcloud import WordCloud

# %%
teste=data.head(5).copy()
print(teste.tagline)
print(teste.tagline.dropna())
# Out:
# 0                                                                               NaN
# 1                                         Roll the dice and unleash the excitement!
# 2                              Still Yelling. Still Fighting. Still Ready for Love.
# 3    Friends are the people who let you be yourself... and never let you forget it.
# 4    Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
# Name: tagline, dtype: object
# 1                                         Roll the dice and unleash the excitement!
# 2                              Still Yelling. Still Fighting. Still Ready for Love.
# 3    Friends are the people who let you be yourself... and never let you forget it.
# 4    Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
# Name: tagline, dtype: object

# %%
title=data.title.dropna();
overview=data.overview.dropna();
tagline=data.tagline.dropna();

# %%
title_joined=' '.join(title)
overview_joined=' '.join(overview)
tagline_joined=' '.join(tagline)
print(tagline_joined)
# Out:
# Roll the dice and unleash the excitement! Still Yelling. Still Fighting. Still Ready for Love. Friends are the people who let you be yourself... and never let you forget it. Just When His World Is Back To Normal... He's In For The Surprise Of His Life! A Los Angeles Crime Saga You are cordially invited to the most surprising merger of the year. The Original Bad Boys. Terror goes into overtime. No limits. No fears. No substitutes. Why can't the most powerful man in the world have the one thing he wants most? Part Dog. Part Wolf. All Hero. Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation. The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime! No one stays at the top forever. Lose your heart and come to your senses. Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who's in for the wildest New year's Eve of his life. New animal
# ...

# %%
title_wordcloud=WordCloud(background_color='White', height=2000, width=4000, max_words=200).generate(title_joined)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud,interpolation='bilinear')
plt.axis=('off')
plt.show()

# %%
title_wordcloud=WordCloud(background_color='White', height=2000, width=4000, max_words=200).generate(tagline_joined)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud,interpolation='bilinear')
plt.axis=('off')
plt.show()

# %%
title_wordcloud=WordCloud(background_color='White', height=2000, width=4000, max_words=200).generate(overview_joined)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud,interpolation='bilinear')
plt.axis=('off')
plt.show()
